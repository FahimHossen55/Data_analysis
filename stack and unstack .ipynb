# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_excel("./Downloads/stocks.xlsx")

# %%
df
# Out:
#             Unnamed: 0     Price Unnamed: 2 Unnamed: 3  \
# 0              Company  Facebook     Google  Microsoft
# 1  2017-06-05 00:00:00       155        955         66
# 2  2017-06-06 00:00:00       150        987         69
# 3  2017-06-07 00:00:00       153        963         62
# 4  2017-06-08 00:00:00       155       1000         61
# 5  2017-06-09 00:00:00       156       1012         66
#
#   Price to earnings ratio (P/E) Unnamed: 5 Unnamed: 6
# 0                      Facebook     Google  Microsoft
# 1                          37.1         32      30.31
# 2                         36.98       31.3      30.56
# 3                         36.78       31.7      30.46
# 4                         36.11       31.2      30.11
# 5                         37.07         30         31

# %%
# Out:
#                     Unnamed: 2                           Unnamed: 3            \
# Price                      150  153   155   156 Facebook        150  153  155
# Unnamed: 0
# 2017-06-05 00:00:00        NaN  NaN   955   NaN      NaN        NaN  NaN   66
# 2017-06-06 00:00:00        987  NaN   NaN   NaN      NaN         69  NaN  NaN
# 2017-06-07 00:00:00        NaN  963   NaN   NaN      NaN        NaN   62  NaN
# 2017-06-08 00:00:00        NaN  NaN  1000   NaN      NaN        NaN  NaN   61
# 2017-06-09 00:00:00        NaN  NaN   NaN  1012      NaN        NaN  NaN  NaN
# Company                    NaN  NaN   NaN   NaN   Google        NaN  NaN  NaN
#
#                                      ... Unnamed: 5                            \
# Price                156   Facebook  ...        150   153   155  156 Facebook
# Unnamed: 0                           ...
# 2017-06-05 00:00:00  NaN        NaN  ...        NaN   NaN    32  NaN      NaN
# ...

# %%
df
# Out:
#                     Unnamed: 2                           Unnamed: 3            \
# Price                      150  153   155   156 Facebook        150  153  155
# Unnamed: 0
# 2017-06-05 00:00:00        NaN  NaN   955   NaN      NaN        NaN  NaN   66
# 2017-06-06 00:00:00        987  NaN   NaN   NaN      NaN         69  NaN  NaN
# 2017-06-07 00:00:00        NaN  963   NaN   NaN      NaN        NaN   62  NaN
# 2017-06-08 00:00:00        NaN  NaN  1000   NaN      NaN        NaN  NaN   61
# 2017-06-09 00:00:00        NaN  NaN   NaN  1012      NaN        NaN  NaN  NaN
# Company                    NaN  NaN   NaN   NaN   Google        NaN  NaN  NaN
#
#                                      ... Unnamed: 5                            \
# Price                156   Facebook  ...        150   153   155  156 Facebook
# Unnamed: 0                           ...
# 2017-06-05 00:00:00  NaN        NaN  ...        NaN   NaN    32  NaN      NaN
# ...

# %%
df
# Out:
#             Unnamed: 0     Price Unnamed: 2 Unnamed: 3  \
# 0              Company  Facebook     Google  Microsoft
# 1  2017-06-05 00:00:00       155        955         66
# 2  2017-06-06 00:00:00       150        987         69
# 3  2017-06-07 00:00:00       153        963         62
# 4  2017-06-08 00:00:00       155       1000         61
# 5  2017-06-09 00:00:00       156       1012         66
#
#   Price to earnings ratio (P/E) Unnamed: 5 Unnamed: 6
# 0                      Facebook     Google  Microsoft
# 1                          37.1         32      30.31
# 2                         36.98       31.3      30.56
# 3                         36.78       31.7      30.46
# 4                         36.11       31.2      30.11
# 5                         37.07         30         31

# %%
df
# Out:
#             Unnamed: 0     Price Unnamed: 2 Unnamed: 3  \
# 0              Company  Facebook     Google  Microsoft
# 1  2017-06-05 00:00:00       155        955         66
# 2  2017-06-06 00:00:00       150        987         69
# 3  2017-06-07 00:00:00       153        963         62
# 4  2017-06-08 00:00:00       155       1000         61
# 5  2017-06-09 00:00:00       156       1012         66
#
#   Price to earnings ratio (P/E) Unnamed: 5 Unnamed: 6
# 0                      Facebook     Google  Microsoft
# 1                          37.1         32      30.31
# 2                         36.98       31.3      30.56
# 3                         36.78       31.7      30.46
# 4                         36.11       31.2      30.11
# 5                         37.07         30         31

# %%
df
# Out:
#             Unnamed: 0     Price Unnamed: 2 Unnamed: 3  \
# 0              Company  Facebook     Google  Microsoft
# 1  2017-06-05 00:00:00       155        955         66
# 2  2017-06-06 00:00:00       150        987         69
# 3  2017-06-07 00:00:00       153        963         62
# 4  2017-06-08 00:00:00       155       1000         61
# 5  2017-06-09 00:00:00       156       1012         66
#
#   Price to earnings ratio (P/E) Unnamed: 5 Unnamed: 6
# 0                      Facebook     Google  Microsoft
# 1                          37.1         32      30.31
# 2                         36.98       31.3      30.56
# 3                         36.78       31.7      30.46
# 4                         36.11       31.2      30.11
# 5                         37.07         30         31

# %%
df.stack(level=0)
# Out:
# 0  Unnamed: 0                                   Company
#    Price                                       Facebook
#    Unnamed: 2                                    Google
#    Unnamed: 3                                 Microsoft
#    Price to earnings ratio (P/E)               Facebook
#    Unnamed: 5                                    Google
#    Unnamed: 6                                 Microsoft
# 1  Unnamed: 0                       2017-06-05 00:00:00
#    Price                                            155
#    Unnamed: 2                                       955
#    Unnamed: 3                                        66
#    Price to earnings ratio (P/E)                   37.1
#    Unnamed: 5                                        32
#    Unnamed: 6                                     30.31
# 2  Unnamed: 0                       2017-06-06 00:00:00
#    Price                                            150
#    Unnamed: 2                                       987
# ...

# %%
df
# Out:
#             Unnamed: 0     Price Unnamed: 2 Unnamed: 3  \
# 0              Company  Facebook     Google  Microsoft
# 1  2017-06-05 00:00:00       155        955         66
# 2  2017-06-06 00:00:00       150        987         69
# 3  2017-06-07 00:00:00       153        963         62
# 4  2017-06-08 00:00:00       155       1000         61
# 5  2017-06-09 00:00:00       156       1012         66
#
#   Price to earnings ratio (P/E) Unnamed: 5 Unnamed: 6
# 0                      Facebook     Google  Microsoft
# 1                          37.1         32      30.31
# 2                         36.98       31.3      30.56
# 3                         36.78       31.7      30.46
# 4                         36.11       31.2      30.11
# 5                         37.07         30         31
