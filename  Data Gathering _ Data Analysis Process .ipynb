# %%
import pandas as pd

# %%
df  = pd.read_csv("./Downloads/aug_train.csv")

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# ## opening a csv file from an url

# %%
import requests

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

data =  pd.read_csv(data)

# %%
data
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# ## Sep parameter

# %%
sep = pd.read_csv("./Downloads/movie_titles_metadata.tsv",sep='\t',names= ["no","name","realease_date","rating","votes","genre"])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_67755/989045660.py in <module>
# ----> 1 sep
#
# NameError: name 'sep' is not defined

# %%
sep
# Out:
#        no                        name realease_date  rating     votes  \
# 0      m0  10 things i hate about you          1999     6.9   62847.0
# 1      m1  1492: conquest of paradise          1992     6.2   10421.0
# 2      m2                  15 minutes          2001     6.1   25854.0
# 3      m3       2001: a space odyssey          1968     8.4  163227.0
# 4      m4                     48 hrs.          1982     6.9   22289.0
# ..    ...                         ...           ...     ...       ...
# 612  m612                    watchmen          2009     7.8  135229.0
# 613  m613                         xxx          2002     5.6   53505.0
# 614  m614                       x-men          2000     7.4  122149.0
# 615  m615          young frankenstein          1974     8.0   57618.0
# 616  m616                   zulu dawn          1979     6.4    1911.0
#
#                                                  genre
# 0                                 ['comedy' 'romance']
# ...

# %% [markdown]
# ##  index_COl_index

# %%
df  = pd.read_csv("./Downloads/aug_train.csv", index_col="enrollee_id")

# %%
df
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %% [markdown]
# ## header perameter a

# %%
df  = pd.read_csv("./Downloads/test.csv" , header=1 , index_col="enrollee_id")

# %%
df
# Out:
#              0      city  city_development_index gender  \
# enrollee_id
# 29725        1   city_40                   0.776   Male
# 11561        2   city_21                   0.624    NaN
# 33241        3  city_115                   0.789    NaN
# 666          4  city_162                   0.767   Male
#
#                  relevent_experience enrolled_university education_level  \
# enrollee_id
# 29725         No relevent experience       no_enrollment        Graduate
# 11561         No relevent experience    Full time course        Graduate
# 33241         No relevent experience                 NaN        Graduate
# 666          Has relevent experience       no_enrollment         Masters
#
#             major_discipline experience company_size    company_type  \
# enrollee_id
# 29725                   STEM         15        50-99         Pvt Ltd
# 11561                   STEM          5          NaN             NaN
# ...

# %% [markdown]
# ## use_cols perameter

# %% [markdown]
# ## it is used for column need specific col

# %%
df  = pd.read_csv("./Downloads/aug_train.csv", usecols=["enrollee_id","gender","education_level"])

# %%
df
# Out:
#        enrollee_id gender education_level
# 0             8949   Male        Graduate
# 1            29725   Male        Graduate
# 2            11561    NaN        Graduate
# 3            33241    NaN        Graduate
# 4              666   Male         Masters
# ...            ...    ...             ...
# 19153         7386   Male        Graduate
# 19154        31398   Male        Graduate
# 19155        24576   Male        Graduate
# 19156         5756   Male     High School
# 19157        23834    NaN  Primary School
#
# [19158 rows x 3 columns]

# %% [markdown]
# ## working with text file

# %%
df  = pd.read_csv("./Downloads/aug_train.txt",sep='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_67755/79650327.py in <module>
# ----> 1 df  = pd.read_csv("./Downloads/aug_train.txt",sep='\t')
#
# ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
# Out:
#       enrollee_id,city,city_development_index,gender,relevent_experience,enrolled_university,education_level,major_discipline,experience,company_size,company_type,last_new_job,training_hours,target
# 0      8949,city_103,0.92,Male,Has relevent experienc...
# 1      29725,city_40,0.7759999999999999,Male,No relev...
# 2      11561,city_21,0.624,,No relevent experience,Fu...
# 3      33241,city_115,0.789,,No relevent experience,,...
# 4      666,city_162,0.767,Male,Has relevent experienc...
# ...                                                  ...
# 19153  7386,city_173,0.878,Male,No relevent experienc...
# 19154  31398,city_103,0.92,Male,Has relevent experien...
# 19155  24576,city_103,0.92,Male,Has relevent experien...
# 19156  5756,city_65,0.802,Male,Has relevent experienc...
# 19157  23834,city_67,0.855,,No relevent experience,no...
#
# [19158 rows x 1 columns]

# %% [markdown]
# ## working with json  and sql format data

# %%
df  = pd.read_json("./Downloads/train.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_67755/872492419.py in <module>
# ----> 1 df  = pd.read_json("./Downloads/train.json", nrows="10")
#
# ~/.local/lib/python3.10/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     789         convert_axes = True
#     790
# --> 791     json_reader = JsonReader(
#     792         path_or_buf,
#     793         orient=orient,
#
# ...

# %%
df
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]
